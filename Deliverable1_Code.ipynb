# %%
from IPython.display import IFrame  
wikiLink="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_sector_composition" 
IFrame(wikiLink, width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_sector_composition"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd

wikiTables=pd.read_html(wikiLink, # link
                        #header=0, # where is the header?
                        flavor='bs4', # helper to translate html
                        attrs={'class': 'wikitable sortable'}) # attributes to identify element(s)

# %%
wikiTables[0]
# Out:
#     Country/Economy  Total GDP (US$MM) Agricultural Industrial Service  \
# 0             World          127800000         6.4%      30.0%   63.6%
# 1             China           23210000         7.9%      40.5%   51.6%
# 2    European Union           20850111         1.6%      25.1%   70.9%
# 3     United States           19490000         0.9%      19.1%   80.0%
# 4             India            9474000        15.4%      23.0%   61.5%
# ..              ...                ...          ...        ...     ...
# 217        Anguilla                175         3.0%      10.5%   86.4%
# 218      Montserrat                167         1.9%       7.8%   90.3%
# 219           Nauru                160         6.1%      33.0%   60.8%
# 220          Tuvalu                 42        24.5%       5.6%   70.0%
# 221            Niue                 10        23.5%      26.9%   49.5%
#
#      Agricultural.1  Industrial.1  Service.1
# 0           8179200      38340000   80514000
# ...

# %%
DF=wikiTables[0]

# %%
type(DF)
# Out:
# pandas.core.frame.DataFrame

# %%
#Making a copy

# %%
DFTest=DF.copy()

# %%
DFTest
# Out:
#     Country/Economy  Total GDP (US$MM) Agricultural Industrial Service  \
# 0             World          127800000         6.4%      30.0%   63.6%
# 1             China           23210000         7.9%      40.5%   51.6%
# 2    European Union           20850111         1.6%      25.1%   70.9%
# 3     United States           19490000         0.9%      19.1%   80.0%
# 4             India            9474000        15.4%      23.0%   61.5%
# ..              ...                ...          ...        ...     ...
# 217        Anguilla                175         3.0%      10.5%   86.4%
# 218      Montserrat                167         1.9%       7.8%   90.3%
# 219           Nauru                160         6.1%      33.0%   60.8%
# 220          Tuvalu                 42        24.5%       5.6%   70.0%
# 221            Niue                 10        23.5%      26.9%   49.5%
#
#      Agricultural.1  Industrial.1  Service.1
# 0           8179200      38340000   80514000
# ...

# %%
#Renaming the columns:

# %%
DFTest.columns=['Country', 'TotalGDP', 'Agriculture%','Industry%', 'Service%', 'Agriculture$', 'Industry$', 'Service$']

# %%
DFTest.head()
# Out:
#           Country   TotalGDP Agriculture% Industry% Service%  Agriculture$  \
# 0           World  127800000         6.4%     30.0%    63.6%       8179200
# 1           China   23210000         7.9%     40.5%    51.6%       1833590
# 2  European Union   20850111         1.6%     25.1%    70.9%        333600
# 3   United States   19490000         0.9%     19.1%    80.0%        175410
# 4           India    9474000        15.4%     23.0%    61.5%       1458996
#
#    Industry$  Service$
# 0   38340000  80514000
# 1    9400050  11976360
# 2    5233350  14782650
# 3    3722590  15592000
# 4    2179020   5826510

# %%
DFTest
# Out:
#             Country   TotalGDP Agriculture% Industry% Service%  Agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      Industry$  Service$
# ...

# %%
DFTest.Country[0]
# Out:
# 'World'

# %%
DFTest.Country
# Out:
# 0               World
# 1               China
# 2      European Union
# 3       United States
# 4               India
#             ...
# 217          Anguilla
# 218        Montserrat
# 219             Nauru
# 220            Tuvalu
# 221              Niue
# Name: Country, Length: 222, dtype: object

# %%
import re

# %%
WhenYouFind='\\s+|\\d+|\\[|\\]'
replaceWith=''

# %%
[re.sub(WhenYouFind,replaceWith,aColumnName) for aColumnName in DFTest.columns]
# Out:
# ['Country',
#  'TotalGDP',
#  'Agriculture%',
#  'Industry%',
#  'Service%',
#  'Agriculture$',
#  'Industry$',
#  'Service$']

# %%
cleaner = lambda INPUT: re.sub(WhenYouFind,replaceWith,INPUT).lower()

# %%
[cleaner(TEXT) for TEXT in DFTest.columns]
# Out:
# ['country',
#  'totalgdp',
#  'agriculture%',
#  'industry%',
#  'service%',
#  'agriculture$',
#  'industry$',
#  'service$']

# %%
DFTest.columns.str.replace(WhenYouFind,replaceWith,regex=True).str.lower()
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$'],
#       dtype='object')

# %%
DFTest.columns=DFTest.columns.str.replace(WhenYouFind,replaceWith,regex=True).str.lower()

# %%
DFTest
# Out:
#             country   totalgdp agriculture% industry% service%  agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# ...

# %%
DFTest.country[0]
# Out:
# 'World'

# %%
DFTest['country']=DFTest.country.str.strip()

# %%
DF=DFTest.copy()

# %%
DF
# Out:
#             country   totalgdp agriculture% industry% service%  agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# ...

# %%
DF.columns
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$'],
#       dtype='object')

# %%
DF.dtypes
# Out:
# country         object
# totalgdp         int64
# agriculture%    object
# industry%       object
# service%        object
# agriculture$     int64
# industry$        int64
# service$         int64
# dtype: object

# %%
DF
# Out:
#             country   totalgdp agriculture% industry% service%  agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# ...

# %%
#I'll get rid of the first and the third (world and EU) rows.

# %%
whichToDrop=[0,2]

# %%
DF.columns
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$'],
#       dtype='object')

# %%
DF.drop(labels=DF.index[whichToDrop],axis=0,inplace=True)

# %%
DF
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 1            China  23210000         7.9%     40.5%    51.6%       1833590
# 3    United States  19490000         0.9%     19.1%    80.0%        175410
# 4            India   9474000        15.4%     23.0%    61.5%       1458996
# 5            Japan   5443000         1.1%     30.1%    68.7%         59873
# 6          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 217       Anguilla       175         3.0%     10.5%    86.4%             5
# 218     Montserrat       167         1.9%      7.8%    90.3%             3
# 219          Nauru       160         6.1%     33.0%    60.8%            10
# 220         Tuvalu        42        24.5%      5.6%    70.0%            10
# 221           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 1      9400050  11976360
# ...

# %%
DF.reset_index(drop=True,inplace=True)

# %%
DF
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 215       Anguilla       175         3.0%     10.5%    86.4%             5
# 216     Montserrat       167         1.9%      7.8%    90.3%             3
# 217          Nauru       160         6.1%     33.0%    60.8%            10
# 218         Tuvalu        42        24.5%      5.6%    70.0%            10
# 219           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0      9400050  11976360
# ...

# %%
#Save it as CSV

# %%
#but first rename it:

# %%
DataGDP=DF.copy()

# %%
DataGDP
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 215       Anguilla       175         3.0%     10.5%    86.4%             5
# 216     Montserrat       167         1.9%      7.8%    90.3%             3
# 217          Nauru       160         6.1%     33.0%    60.8%            10
# 218         Tuvalu        42        24.5%      5.6%    70.0%            10
# 219           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0      9400050  11976360
# ...

# %% [markdown]
# # Saving it as CSV:

# %%
DataGDP.to_csv("DataGDP.csv",index=False)

# %% [markdown]
# # The first data set is ready. Now to the second one: Data ISO

# %%
# link to the data in CSV format
linkDataIso='https://github.com/dghnyldz/computational-thinking/raw/main/isodata.csv'

# using 'read_csv' with a link
DataIso=pd.read_csv(linkDataIso)

# %%
DataIso.columns
# Out:
# Index(['Countryname', 'Officialstatename', 'InternetccTLD', 'iso2', 'iso3'], dtype='object')

# %%
DataIso
# Out:
#            Countryname                               Officialstatename  \
# 0          Afghanistan             The Islamic Republic of Afghanistan
# 1        Åland Islands                                           Åland
# 2              Albania                         The Republic of Albania
# 3              Algeria     The People's Democratic Republic of Algeria
# 4       American Samoa                 The Territory of American Samoa
# ..                 ...                                             ...
# 244  Wallis and Futuna  The Territory of the Wallis and Futuna Islands
# 245     Western Sahara            The Sahrawi Arab Democratic Republic
# 246              Yemen                           The Republic of Yemen
# 247             Zambia                          The Republic of Zambia
# 248           Zimbabwe                        The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .ax   AX  ALA
# ...

# %%
DataGDP
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 215       Anguilla       175         3.0%     10.5%    86.4%             5
# 216     Montserrat       167         1.9%      7.8%    90.3%             3
# 217          Nauru       160         6.1%     33.0%    60.8%            10
# 218         Tuvalu        42        24.5%      5.6%    70.0%            10
# 219           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0      9400050  11976360
# ...

# %%
#column positions to drop
whichToDrop=[1]

#dropping and updating the data frame
DataIso.drop(labels=DataIso.columns[whichToDrop],axis=1,inplace=True)

# %%
DataIso
# Out:
#            Countryname InternetccTLD iso2 iso3
# 0          Afghanistan           .af   AF  AFG
# 1        Åland Islands           .ax   AX  ALA
# 2              Albania           .al   AL  ALB
# 3              Algeria           .dz   DZ  DZA
# 4       American Samoa           .as   AS  ASM
# ..                 ...           ...  ...  ...
# 244  Wallis and Futuna           .wf   WF  WLF
# 245     Western Sahara           NaN   EH  ESH
# 246              Yemen           .ye   YE  YEM
# 247             Zambia           .zm   ZM  ZMB
# 248           Zimbabwe           .zw   ZW  ZWE
#
# [249 rows x 4 columns]

# %%
# merge 'outer' keeps all matched and unmatched
# merge 'indicator' will tell you if the key was found in 'both' or only in one of them
Combined=DataGDP.merge(DataIso,left_on="country",right_on="Countryname",how='outer',indicator='True')

# %%
Combined.columns
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$', 'Countryname', 'InternetccTLD',
#        'iso2', 'iso3', 'True'],
#       dtype='object')

# %%
Combined['True'].value_counts()
# Out:
# both          177
# right_only     72
# left_only      43
# Name: True, dtype: int64

# %%
Combined[Combined['True']=='left_only'].country
# Out:
# 1                          United States
# 5                                 Russia
# 8                         United Kingdom
# 13                          Korea, South
# 17                                  Iran
# 21                                Taiwan
# 26                           Netherlands
# 28                           Philippines
# 31                  United Arab Emirates
# 34                               Vietnam
# 46                             Venezuela
# 48                        Czech Republic
# 52                                 Burma
# 70                                 Sudan
# 71                    Dominican Republic
# 74                              Tanzania
# 85                         Cote d'Ivoire
# 93                               Bolivia
# 97                                 Macau
# 102    Congo, Democratic Republic of the
# 109                                Syria
# 110                                 Laos
# 116                         Korea, North
# ...

# %%
Combined[Combined['True']=='right_only'].Countryname
# Out:
# 220                       Åland Islands
# 221                          Antarctica
# 222                       Bahamas (the)
# 223    Bolivia (Plurinational State of)
# 224         Bonaire Sint Eustatius Saba
#                      ...
# 287                            Viet Nam
# 288            Virgin Islands (British)
# 289               Virgin Islands (U.S.)
# 290                   Wallis and Futuna
# 291                      Western Sahara
# Name: Countryname, Length: 72, dtype: object

# %%
# The countries unmatched
UnmatchedLeft=Combined[Combined['True']=='left_only'].country.to_list()
UnmatchedRight=Combined[Combined['True']=='right_only'].Countryname.to_list()

# %%
UnmatchedLeft[0]
# Out:
# 'United States'

# %%
from thefuzz import process
process.extractOne(UnmatchedLeft[0], UnmatchedRight)
# Out:
# C:\Users\dagha\anaconda3\lib\site-packages\thefuzz\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# ('United States Minor Outlying Islands (the)', 90)

# %%
process.extract(UnmatchedLeft[0], UnmatchedRight,limit=3)
# Out:
# [('United States Minor Outlying Islands (the)', 90),
#  ('United States of America (the)', 90),
#  ('Micronesia (Federated States of)', 86)]

# %%
UnmatchedLeft=Combined[Combined['True']=='left_only'].country.to_list()
UnmatchedLeft
# Out:
# ['United States',
#  'Russia',
#  'United Kingdom',
#  'Korea, South',
#  'Iran',
#  'Taiwan',
#  'Netherlands',
#  'Philippines',
#  'United Arab Emirates',
#  'Vietnam',
#  'Venezuela',
#  'Czech Republic',
#  'Burma',
#  'Sudan',
#  'Dominican Republic',
#  'Tanzania',
#  "Cote d'Ivoire",
#  'Bolivia',
#  'Macau',
#  'Congo, Democratic Republic of the',
#  'Syria',
#  'Laos',
#  'Korea, North',
#  'Brunei',
#  'Congo, Republic of the',
#  'Moldova',
#  'Niger',
#  'Kosovo',
#  'Bahamas, The',
#  'Gambia, The',
#  'Central African Republic',
#  'Curacao',
#  'Cayman Islands',
#  'Faroe Islands',
#  'Comoros',
#  'Northern Mariana Islands',
#  'Turks and Caicos Islands',
#  'Saint Martin',
#  'British Virgin Islands',
#  'Sint Maarten',
#  'Micronesia, Federated States of',
#  'Cook Islands',
#  'Marshall Islands']

# %%
[(left, process.extractOne(left, UnmatchedRight)) for left in sorted(UnmatchedLeft)]
# Out:
# [('Bahamas, The', ('Bahamas (the)', 100)),
#  ('Bolivia', ('Bolivia (Plurinational State of)', 90)),
#  ('British Virgin Islands', ('Virgin Islands (British)', 95)),
#  ('Brunei', ('Brunei Darussalam', 90)),
#  ('Burma', ('Curaçao', 55)),
#  ('Cayman Islands', ('Cayman Islands (the)', 95)),
#  ('Central African Republic', ('Central African Republic (the)', 95)),
#  ('Comoros', ('Comoros (the)', 90)),
#  ('Congo, Democratic Republic of the',
#   ('Congo (the Democratic Republic of the)', 95)),
#  ('Congo, Republic of the', ('Bahamas (the)', 86)),
#  ('Cook Islands', ('Cook Islands (the)', 95)),
#  ("Cote d'Ivoire", ("Côte d'Ivoire", 96)),
#  ('Curacao', ('Curaçao', 92)),
#  ('Czech Republic', ('Central African Republic (the)', 86)),
#  ('Dominican Republic', ('Dominican Republic (the)', 95)),
#  ('Faroe Islands', ('Faroe Islands (the)', 95)),
#  ('Gambia, The', ('Gambia (the)', 100)),
#  ('Iran', ('Iran (Islamic Republic of)', 90)),
# ...

# %%
TotallyWrong=[('Burma', ('Curaçao', 55)),
              ('Congo, Republic of the', ('Bahamas (the)', 86)),
              ('Czech Republic', ('Central African Republic (the)', 86)),
              ('Korea, North', ("Korea (the Democratic People's Republic of)", 86)),
              ('Korea, South', ("Korea (the Democratic People's Republic of)", 86)),
              ('Kosovo', ('Moldova (the Republic of)', 45)), ('Laos', ('Brunei Darussalam', 51)), ('Sudan', ('South Sudan', 90)), ('United States', ('United States Minor Outlying Islands (the)', 90)),]

# %%
omitLeft=[leftName for (leftName,rightFuzzy) in TotallyWrong] #parenthesis not needed
omitLeft
# Out:
# ['Burma',
#  'Congo, Republic of the',
#  'Czech Republic',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Laos',
#  'Sudan',
#  'United States']

# %%
{process.extractOne(left, UnmatchedRight)[0]:left for left in UnmatchedLeft if left not in omitLeft}
# Out:
# {'Russian Federation (the)': 'Russia',
#  'United Kingdom of Great Britain and Northern Ireland (the)': 'United Kingdom',
#  'Iran (Islamic Republic of)': 'Iran',
#  'Taiwan (Province of China)': 'Taiwan',
#  'Netherlands (the)': 'Netherlands',
#  'Philippines (the)': 'Philippines',
#  'United Arab Emirates (the)': 'United Arab Emirates',
#  'Viet Nam': 'Vietnam',
#  'Venezuela (Bolivarian Republic of)': 'Venezuela',
#  'Dominican Republic (the)': 'Dominican Republic',
#  'Tanzania, the United Republic of': 'Tanzania',
#  "Côte d'Ivoire": "Cote d'Ivoire",
#  'Bolivia (Plurinational State of)': 'Bolivia',
#  'Macao': 'Macau',
#  'Congo (the Democratic Republic of the)': 'Congo, Democratic Republic of the',
#  'Syrian Arab Republic (the)': 'Syria',
#  'Brunei Darussalam': 'Brunei',
#  'Moldova (the Republic of)': 'Moldova',
#  'Niger (the)': 'Niger',
#  'Bahamas (the)': 'Bahamas, The',
#  'Gambia (the)': 'Gambia, The',
#  'Central African Republic (the)': 'Central African Republic',
# ...

# %%
changesRight={process.extractOne(left, UnmatchedRight)[0]:left for left in UnmatchedLeft if left not in omitLeft}
DataIso.Countryname.replace(changesRight,inplace=True)

# %%
# dict of manual changes
bruteForceChanges={'Korea (the Republic of)':'South Korea', 
                'United States of America (the)':'United States',
                'Czechia':'Czech Republic', 
                'Congo, Republic of the':'Republic of the Congo',
                'Sudan (the)':'Sudan',
                "Lao People's Democratic Republic (the)":'Laos'}

# %%
DataIso.Countryname.replace(bruteForceChanges,inplace=True)

# %%
DataGDP.shape
# Out:
# (220, 8)

# %%
# redoing merge
Combined=DataGDP.merge(DataIso,left_on="country",right_on="Countryname")

# current dimension
Combined.shape
# Out:
# (215, 12)

# %%
UnmatchedLeft[0]
# Out:
# 'United States'

# %%
UnmatchedLeft
# Out:
# ['United States',
#  'Russia',
#  'United Kingdom',
#  'Korea, South',
#  'Iran',
#  'Taiwan',
#  'Netherlands',
#  'Philippines',
#  'United Arab Emirates',
#  'Vietnam',
#  'Venezuela',
#  'Czech Republic',
#  'Burma',
#  'Sudan',
#  'Dominican Republic',
#  'Tanzania',
#  "Cote d'Ivoire",
#  'Bolivia',
#  'Macau',
#  'Congo, Democratic Republic of the',
#  'Syria',
#  'Laos',
#  'Korea, North',
#  'Brunei',
#  'Congo, Republic of the',
#  'Moldova',
#  'Niger',
#  'Kosovo',
#  'Bahamas, The',
#  'Gambia, The',
#  'Central African Republic',
#  'Curacao',
#  'Cayman Islands',
#  'Faroe Islands',
#  'Comoros',
#  'Northern Mariana Islands',
#  'Turks and Caicos Islands',
#  'Saint Martin',
#  'British Virgin Islands',
#  'Sint Maarten',
#  'Micronesia, Federated States of',
#  'Cook Islands',
#  'Marshall Islands']

# %%
UnmatchedLeft[12]
# Out:
# 'Burma'

# %%
process.extract(UnmatchedLeft[12], UnmatchedRight,limit=3)
# Out:
# [('Curaçao', 55),
#  ('Bolivia (Plurinational State of)', 54),
#  ('Northern Mariana Islands (the)', 54)]

# %%
process.extract(UnmatchedLeft[12], UnmatchedRight,limit=8)
# Out:
# [('Curaçao', 55),
#  ('Bolivia (Plurinational State of)', 54),
#  ('Northern Mariana Islands (the)', 54),
#  ('Guam', 44),
#  ('Macao', 40),
#  ('Bahamas (the)', 36),
#  ('Bonaire\xa0Sint Eustatius\xa0Saba', 36),
#  ('Bouvet Island', 36)]

# %%
process.extract(UnmatchedLeft[27], UnmatchedRight,limit=3)
# Out:
# [('Moldova (the Republic of)', 45),
#  ('Bolivia (Plurinational State of)', 30),
#  ('Bouvet Island', 30)]

# %%
# Some countries just do not exist in the ISO Data, so I omitted those.

# %%
Combined
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 210       Anguilla       175         3.0%     10.5%    86.4%             5
# 211     Montserrat       167         1.9%      7.8%    90.3%             3
# 212          Nauru       160         6.1%     33.0%    60.8%            10
# 213         Tuvalu        42        24.5%      5.6%    70.0%            10
# 214           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$    Countryname InternetccTLD iso2 iso3
# ...

# %%
#Dropping the unnecessary column:
Combined.drop(["Countryname"],axis=1,inplace=True)
Combined
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 210       Anguilla       175         3.0%     10.5%    86.4%             5
# 211     Montserrat       167         1.9%      7.8%    90.3%             3
# 212          Nauru       160         6.1%     33.0%    60.8%            10
# 213         Tuvalu        42        24.5%      5.6%    70.0%            10
# 214           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$ InternetccTLD iso2 iso3
# ...

# %%
#Rename the column names so they look better:

# %%
Combined.columns=['Country', 'TotalGDPinMillions', 'Agriculture%','Industry%', 'Service%', 'Agriculture$', 'Industry$', 'Service$', 'InternetccTLD', 'ISO2', 'ISO3']

# %%
Combined
# Out:
#            Country  TotalGDPinMillions Agriculture% Industry% Service%  \
# 0            China            23210000         7.9%     40.5%    51.6%
# 1    United States            19490000         0.9%     19.1%    80.0%
# 2            India             9474000        15.4%     23.0%    61.5%
# 3            Japan             5443000         1.1%     30.1%    68.7%
# 4          Germany             4199000         0.7%     30.7%    68.6%
# ..             ...                 ...          ...       ...      ...
# 210       Anguilla                 175         3.0%     10.5%    86.4%
# 211     Montserrat                 167         1.9%      7.8%    90.3%
# 212          Nauru                 160         6.1%     33.0%    60.8%
# 213         Tuvalu                  42        24.5%      5.6%    70.0%
# 214           Niue                  10        23.5%     26.9%    49.5%
#
#      Agriculture$  Industry$  Service$ InternetccTLD ISO2 ISO3
# ...

# %%
#Save it as CSV:

Combined.to_csv('Combined.csv',index=False)

# %% [markdown]
# # We merged 2 datasets. Now we'll add a third one to this "Combined" dataset, which is the CO2 emissions and population by country:

# %%
# link to the data in CSV format
linkDataCO2='https://github.com/dghnyldz/computational-thinking/raw/main/DataCO2.csv'

# using 'read_csv' with a link
DataCO2=pd.read_csv(linkDataCO2)

# %%
DataCO2
# Out:
#                country  totalCO2emission      pop2021
# 0                China           2806634  1444216.107
# 1        United States           1432855   332915.073
# 2                India            610411  1393409.038
# 3               Russia            465052   145912.025
# 4                Japan            331074   126050.804
# ..                 ...               ...          ...
# 212         Montserrat                13        4.977
# 213      Liechtenstein                12       38.250
# 214  Wallis and Futuna                 6       11.094
# 215             Tuvalu                 3       11.931
# 216               Niue                 3        1.619
#
# [217 rows x 3 columns]

# %%
# Rename the columns:

# %%
DataCO2.columns=['country', 'CO2x1000', 'Population']
DataCO2
# Out:
#                country  CO2x1000   Population
# 0                China   2806634  1444216.107
# 1        United States   1432855   332915.073
# 2                India    610411  1393409.038
# 3               Russia    465052   145912.025
# 4                Japan    331074   126050.804
# ..                 ...       ...          ...
# 212         Montserrat        13        4.977
# 213      Liechtenstein        12       38.250
# 214  Wallis and Futuna         6       11.094
# 215             Tuvalu         3       11.931
# 216               Niue         3        1.619
#
# [217 rows x 3 columns]

# %%
#Now let's integrate this to out "Combined" data frame to finalize our dataset:

# %%
Combined
# Out:
#            Country  TotalGDPinMillions Agriculture% Industry% Service%  \
# 0            China            23210000         7.9%     40.5%    51.6%
# 1    United States            19490000         0.9%     19.1%    80.0%
# 2            India             9474000        15.4%     23.0%    61.5%
# 3            Japan             5443000         1.1%     30.1%    68.7%
# 4          Germany             4199000         0.7%     30.7%    68.6%
# ..             ...                 ...          ...       ...      ...
# 210       Anguilla                 175         3.0%     10.5%    86.4%
# 211     Montserrat                 167         1.9%      7.8%    90.3%
# 212          Nauru                 160         6.1%     33.0%    60.8%
# 213         Tuvalu                  42        24.5%      5.6%    70.0%
# 214           Niue                  10        23.5%     26.9%    49.5%
#
#      Agriculture$  Industry$  Service$ InternetccTLD ISO2 ISO3
# ...

# %%
FinalData=Combined.merge(DataCO2,left_on="Country",right_on="country",how='outer',indicator='True')

# %%
FinalData.columns
# Out:
# Index(['Country', 'TotalGDPinMillions', 'Agriculture%', 'Industry%',
#        'Service%', 'Agriculture$', 'Industry$', 'Service$', 'InternetccTLD',
#        'ISO2', 'ISO3', 'country', 'CO2x1000', 'Population', 'True'],
#       dtype='object')

# %%
# explore matched and unmatched counts:
FinalData['True'].value_counts()
# Out:
# both          197
# right_only     20
# left_only      18
# Name: True, dtype: int64

# %%
FinalData[FinalData['True']=='left_only'].Country
# Out:
# 78                           Puerto Rico
# 83                         Cote d'Ivoire
# 100    Congo, Democratic Republic of the
# 127                      North Macedonia
# 148                         Bahamas, The
# 157                               Monaco
# 161                          Isle of Man
# 166                               Jersey
# 167                          Gambia, The
# 172                           Cabo Verde
# 174                             Guernsey
# 176                              Andorra
# 185                           San Marino
# 192     Saint Vincent and the Grenadines
# 193             Northern Mariana Islands
# 198                       American Samoa
# 203                         Sint Maarten
# 204      Micronesia, Federated States of
# Name: Country, dtype: object

# %%
FinalData[FinalData['True']=='right_only'].country
# Out:
# 215                         South Korea
# 216                         North Korea
# 217                             Myanmar
# 218                         Ivory Coast
# 219                            Dr Congo
# 220                             Reunion
# 221               Republic of The Congo
# 222                           Palestine
# 223                          Guadeloupe
# 224                             Bahamas
# 225                          Martinique
# 226                         South Sudan
# 227                       French Guiana
# 228                              Gambia
# 229                          Cape Verde
# 230                             andorra
# 231    Saint Vincent and The Grenadines
# 232                          Micronesia
# 233                    Falkland Islands
# 234                   Wallis and Futuna
# Name: country, dtype: object

# %%
# The countries unmatched
UnmatchedLeft=FinalData[FinalData['True']=='left_only'].Country.to_list()
UnmatchedRight=FinalData[FinalData['True']=='right_only'].country.to_list()

# %%
UnmatchedLeft[0]
# Out:
# 'Puerto Rico'

# %%
UnmatchedRight[0]
# Out:
# 'South Korea'

# %%
process.extractOne(UnmatchedLeft[0], UnmatchedRight)
# Out:
# ('Dr Congo', 42)

# %%
process.extract(UnmatchedLeft[0], UnmatchedRight,limit=3)
# Out:
# [('Dr Congo', 42), ('Reunion', 41), ('Republic of The Congo', 40)]

# %%
UnmatchedLeft=FinalData[FinalData['True']=='left_only'].Country.to_list()
UnmatchedLeft
# Out:
# ['Puerto Rico',
#  "Cote d'Ivoire",
#  'Congo, Democratic Republic of the',
#  'North Macedonia',
#  'Bahamas, The',
#  'Monaco',
#  'Isle of Man',
#  'Jersey',
#  'Gambia, The',
#  'Cabo Verde',
#  'Guernsey',
#  'Andorra',
#  'San Marino',
#  'Saint Vincent and the Grenadines',
#  'Northern Mariana Islands',
#  'American Samoa',
#  'Sint Maarten',
#  'Micronesia, Federated States of']

# %%
[(left, process.extractOne(left, UnmatchedRight)) for left in sorted(UnmatchedLeft)]
# Out:
# [('American Samoa', ('Gambia', 45)),
#  ('Andorra', ('andorra', 100)),
#  ('Bahamas, The', ('Bahamas', 90)),
#  ('Cabo Verde', ('Cape Verde', 80)),
#  ('Congo, Democratic Republic of the', ('Dr Congo', 86)),
#  ("Cote d'Ivoire", ('Ivory Coast', 64)),
#  ('Gambia, The', ('Gambia', 90)),
#  ('Guernsey', ('Guadeloupe', 44)),
#  ('Isle of Man', ('Republic of The Congo', 86)),
#  ('Jersey', ('Cape Verde', 50)),
#  ('Micronesia, Federated States of', ('Micronesia', 90)),
#  ('Monaco', ('Republic of The Congo', 50)),
#  ('North Macedonia', ('North Korea', 59)),
#  ('Northern Mariana Islands', ('Falkland Islands', 86)),
#  ('Puerto Rico', ('Dr Congo', 42)),
#  ('Saint Vincent and the Grenadines',
#   ('Saint Vincent and The Grenadines', 100)),
#  ('San Marino', ('Myanmar', 59)),
#  ('Sint Maarten', ('Martinique', 52))]

# %%
TotallyWrong=[('American Samoa', ('Gambia', 45)), ('Guernsey', ('Guadeloupe', 44)), ('Isle of Man', ('Republic of The Congo', 86)), ('Jersey', ('Cape Verde', 50)), ('Monaco', ('Republic of The Congo', 50)), ('North Macedonia', ('North Korea', 59)), ('Northern Mariana Islands', ('Falkland Islands', 86)), ('Puerto Rico', ('Dr Congo', 42)), ('San Marino', ('Myanmar', 59)), ('Sint Maarten', ('Martinique', 52))]

# %%
omitLeft=[leftName for (leftName,rightFuzzy) in TotallyWrong] #parenthesis not needed
omitLeft
# Out:
# ['American Samoa',
#  'Guernsey',
#  'Isle of Man',
#  'Jersey',
#  'Monaco',
#  'North Macedonia',
#  'Northern Mariana Islands',
#  'Puerto Rico',
#  'San Marino',
#  'Sint Maarten']

# %%
{process.extractOne(left, UnmatchedRight)[0]:left for left in UnmatchedLeft if left not in omitLeft}
# Out:
# {'Ivory Coast': "Cote d'Ivoire",
#  'Dr Congo': 'Congo, Democratic Republic of the',
#  'Bahamas': 'Bahamas, The',
#  'Gambia': 'Gambia, The',
#  'Cape Verde': 'Cabo Verde',
#  'andorra': 'Andorra',
#  'Saint Vincent and The Grenadines': 'Saint Vincent and the Grenadines',
#  'Micronesia': 'Micronesia, Federated States of'}

# %%
changesRight={process.extractOne(left, UnmatchedRight)[0]:left for left in UnmatchedLeft if left not in omitLeft}
DataCO2.country.replace(changesRight,inplace=True)

# %% [markdown]
# # The rest (omitted ones) do not exist in the other dataset, so I will keep them omitted.

# %%
Combined.shape
# Out:
# (215, 11)

# %%
DataCO2.shape
# Out:
# (217, 3)

# %%
# redoing merge
FinalData=Combined.merge(DataCO2,left_on="Country",right_on="country")

# current dimension
FinalData.shape
# Out:
# (205, 14)

# %%
FinalData
# Out:
#            Country  TotalGDPinMillions Agriculture% Industry% Service%  \
# 0            China            23210000         7.9%     40.5%    51.6%
# 1    United States            19490000         0.9%     19.1%    80.0%
# 2            India             9474000        15.4%     23.0%    61.5%
# 3            Japan             5443000         1.1%     30.1%    68.7%
# 4          Germany             4199000         0.7%     30.7%    68.6%
# ..             ...                 ...          ...       ...      ...
# 200       Anguilla                 175         3.0%     10.5%    86.4%
# 201     Montserrat                 167         1.9%      7.8%    90.3%
# 202          Nauru                 160         6.1%     33.0%    60.8%
# 203         Tuvalu                  42        24.5%      5.6%    70.0%
# 204           Niue                  10        23.5%     26.9%    49.5%
#
#      Agriculture$  Industry$  Service$ InternetccTLD ISO2 ISO3        country  \
# ...

# %%
# I will drop the "country" column:

# %%
FinalData.drop(["country"],axis=1,inplace=True)
FinalData
# Out:
#            Country  TotalGDPinMillions Agriculture% Industry% Service%  \
# 0            China            23210000         7.9%     40.5%    51.6%
# 1    United States            19490000         0.9%     19.1%    80.0%
# 2            India             9474000        15.4%     23.0%    61.5%
# 3            Japan             5443000         1.1%     30.1%    68.7%
# 4          Germany             4199000         0.7%     30.7%    68.6%
# ..             ...                 ...          ...       ...      ...
# 200       Anguilla                 175         3.0%     10.5%    86.4%
# 201     Montserrat                 167         1.9%      7.8%    90.3%
# 202          Nauru                 160         6.1%     33.0%    60.8%
# 203         Tuvalu                  42        24.5%      5.6%    70.0%
# 204           Niue                  10        23.5%     26.9%    49.5%
#
#      Agriculture$  Industry$  Service$ InternetccTLD ISO2 ISO3  CO2x1000  \
# ...

# %% [markdown]
# # Save as CSV:

# %%
FinalData.to_csv("FinalData.csv",index=False)

# %% [markdown]
# # Saving for R:

# %%
pip show rpy2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: rpy2

# %%
pip install rpy2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Downloading rpy2-3.4.5.tar.gz (194 kB)
# ...
#
# ...
#   Created wheel for rpy2: filename=rpy2-3.4.5-py3-none-any.whl size=198864 sha256=3277cb3c5ff3cfdbbea21d24acd2a006a83aa65c829868a7fcf5127a8542ab58
#   Stored in directory: c:\users\dagha\appdata\local\pip\cache\wheels\36\d1\63\882c1f63d21bcf817b7db960b9536a747d4258daeaace0edd4
# Successfully built rpy2
# ...

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(FinalData,file="FinalData.RDS")
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x0000016410CCA780> [RTYPES.NILSXP]
