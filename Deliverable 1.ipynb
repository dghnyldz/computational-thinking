# %%
from IPython.display import IFrame  
wikiLink="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_sector_composition" 
IFrame(wikiLink, width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_sector_composition"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd

wikiTables=pd.read_html(wikiLink, # link
                        #header=0, # where is the header?
                        flavor='bs4', # helper to translate html
                        attrs={'class': 'wikitable sortable'}) # attributes to identify element(s)

# %%
wikiTables[0]
# Out:
#     Country/Economy  Total GDP (US$MM) Agricultural Industrial Service  \
# 0             World          127800000         6.4%      30.0%   63.6%
# 1             China           23210000         7.9%      40.5%   51.6%
# 2    European Union           20850111         1.6%      25.1%   70.9%
# 3     United States           19490000         0.9%      19.1%   80.0%
# 4             India            9474000        15.4%      23.0%   61.5%
# ..              ...                ...          ...        ...     ...
# 217        Anguilla                175         3.0%      10.5%   86.4%
# 218      Montserrat                167         1.9%       7.8%   90.3%
# 219           Nauru                160         6.1%      33.0%   60.8%
# 220          Tuvalu                 42        24.5%       5.6%   70.0%
# 221            Niue                 10        23.5%      26.9%   49.5%
#
#      Agricultural.1  Industrial.1  Service.1
# 0           8179200      38340000   80514000
# 1           1833590       9400050   11976360
# 2            333600       5233350   14782650
# 3            175410       3722590   15592000
# 4           1458996       2179020    5826510
# ..              ...           ...        ...
# 217               5            18        151
# 218               3            13        151
# 219              10            53         97
# 220              10             2         29
# 221               2             3          5
#
# [222 rows x 8 columns]

# %%
DF=wikiTables[0]

# %%
type(DF)
# Out:
# pandas.core.frame.DataFrame

# %%
#Making a copy

# %%
DFTest=DF.copy()

# %%
DFTest
# Out:
#     Country/Economy  Total GDP (US$MM) Agricultural Industrial Service  \
# 0             World          127800000         6.4%      30.0%   63.6%
# 1             China           23210000         7.9%      40.5%   51.6%
# 2    European Union           20850111         1.6%      25.1%   70.9%
# 3     United States           19490000         0.9%      19.1%   80.0%
# 4             India            9474000        15.4%      23.0%   61.5%
# ..              ...                ...          ...        ...     ...
# 217        Anguilla                175         3.0%      10.5%   86.4%
# 218      Montserrat                167         1.9%       7.8%   90.3%
# 219           Nauru                160         6.1%      33.0%   60.8%
# 220          Tuvalu                 42        24.5%       5.6%   70.0%
# 221            Niue                 10        23.5%      26.9%   49.5%
#
#      Agricultural.1  Industrial.1  Service.1
# 0           8179200      38340000   80514000
# 1           1833590       9400050   11976360
# 2            333600       5233350   14782650
# 3            175410       3722590   15592000
# 4           1458996       2179020    5826510
# ..              ...           ...        ...
# 217               5            18        151
# 218               3            13        151
# 219              10            53         97
# 220              10             2         29
# 221               2             3          5
#
# [222 rows x 8 columns]

# %%
#Renaming the columns:

# %%
DFTest.columns=['Country', 'TotalGDP', 'Agriculture%','Industry%', 'Service%', 'Agriculture$', 'Industry$', 'Service$']

# %%
DFTest.head()
# Out:
#           Country   TotalGDP Agriculture% Industry% Service%  Agriculture$  \
# 0           World  127800000         6.4%     30.0%    63.6%       8179200
# 1           China   23210000         7.9%     40.5%    51.6%       1833590
# 2  European Union   20850111         1.6%     25.1%    70.9%        333600
# 3   United States   19490000         0.9%     19.1%    80.0%        175410
# 4           India    9474000        15.4%     23.0%    61.5%       1458996
#
#    Industry$  Service$
# 0   38340000  80514000
# 1    9400050  11976360
# 2    5233350  14782650
# 3    3722590  15592000
# 4    2179020   5826510

# %%
DFTest
# Out:
#             Country   TotalGDP Agriculture% Industry% Service%  Agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      Industry$  Service$
# 0     38340000  80514000
# 1      9400050  11976360
# 2      5233350  14782650
# 3      3722590  15592000
# 4      2179020   5826510
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [222 rows x 8 columns]

# %%
DF.country[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2643974428.py in <module>
# ----> 1 DF.country[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'country'

# %%
DFTest.country
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2337669645.py in <module>
# ----> 1 DFTest.country
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'country'

# %%
DFTest.country[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/1388923850.py in <module>
# ----> 1 DFTest.country[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'country'

# %%
DFTest
# Out:
#             Country   TotalGDP Agriculture% Industry% Service%  Agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      Industry$  Service$
# 0     38340000  80514000
# 1      9400050  11976360
# 2      5233350  14782650
# 3      3722590  15592000
# 4      2179020   5826510
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [222 rows x 8 columns]

# %%
DFTest.Country[0]
# Out:
# 'World'

# %%
DFTest.Country
# Out:
# 0               World
# 1               China
# 2      European Union
# 3       United States
# 4               India
#             ...
# 217          Anguilla
# 218        Montserrat
# 219             Nauru
# 220            Tuvalu
# 221              Niue
# Name: Country, Length: 222, dtype: object

# %%
DF['Country']=DF.Country.str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/3569991637.py in <module>
# ----> 1 DF['Country']=DF.Country.str.strip()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
DFTest['Country']=DF.Country.str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/4274520794.py in <module>
# ----> 1 DFTest['Country']=DF.Country.str.strip()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
DFTest['Country']=DFTest.Country.str.strip()

# %%
byeSpaces= lambda COLUMN:COLUMN.str.strip()

DFTest.apply(byeSpaces)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2294309559.py in <module>
#       1 byeSpaces= lambda COLUMN:COLUMN.str.strip()
#       2
# ----> 3 DFTest.apply(byeSpaces)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp/ipykernel_12024/2294309559.py in <lambda>(COLUMN)
# ----> 1 byeSpaces= lambda COLUMN:COLUMN.str.strip()
#       2
#       3 DFTest.apply(byeSpaces)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
DFTest
# Out:
#             Country   TotalGDP Agriculture% Industry% Service%  Agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      Industry$  Service$
# 0     38340000  80514000
# 1      9400050  11976360
# 2      5233350  14782650
# 3      3722590  15592000
# 4      2179020   5826510
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [222 rows x 8 columns]

# %%
import re

# %%
WhenYouFind='\\s+|\\d+|\\[|\\]'
replaceWith=''

# %%
re.sub(WhenYouFind,replaceWith,DFTest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2766619701.py in <module>
# ----> 1 re.sub(WhenYouFind,replaceWith,DFTest)
#
# ~\anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
[re.sub(WhenYouFind,replaceWith,aColumnName) for aColumnName in DFTest.columns]
# Out:
# ['Country',
#  'TotalGDP',
#  'Agriculture%',
#  'Industry%',
#  'Service%',
#  'Agriculture$',
#  'Industry$',
#  'Service$']

# %%
cleaner = lambda INPUT: re.sub(WhenYouFind,replaceWith,INPUT).lower()

# %%
[cleaner(TEXT) for TEXT in DFTest.columns]
# Out:
# ['country',
#  'totalgdp',
#  'agriculture%',
#  'industry%',
#  'service%',
#  'agriculture$',
#  'industry$',
#  'service$']

# %%
DFTest.columns.str.replace(WhenYouFind,replaceWith,regex=True).str.lower()
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$'],
#       dtype='object')

# %%
DFTest.columns=DFTest.columns.str.replace(WhenYouFind,replaceWith,regex=True).str.lower()

# %%
DFTest
# Out:
#             country   totalgdp agriculture% industry% service%  agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0     38340000  80514000
# 1      9400050  11976360
# 2      5233350  14782650
# 3      3722590  15592000
# 4      2179020   5826510
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [222 rows x 8 columns]

# %%
DFTest.country[0]
# Out:
# 'World'

# %%
DFTest['country']=DFTest.country.str.strip()

# %%
byeSpaces= lambda COLUMN:COLUMN.str.strip()

DFTest.apply(byeSpaces)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2294309559.py in <module>
#       1 byeSpaces= lambda COLUMN:COLUMN.str.strip()
#       2
# ----> 3 DFTest.apply(byeSpaces)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp/ipykernel_12024/2294309559.py in <lambda>(COLUMN)
# ----> 1 byeSpaces= lambda COLUMN:COLUMN.str.strip()
#       2
#       3 DFTest.apply(byeSpaces)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
DF=DFTest.copy()

# %%
DF
# Out:
#             country   totalgdp agriculture% industry% service%  agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0     38340000  80514000
# 1      9400050  11976360
# 2      5233350  14782650
# 3      3722590  15592000
# 4      2179020   5826510
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [222 rows x 8 columns]

# %%
DF.columns
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$'],
#       dtype='object')

# %%
byeSpaces= lambda column:column.str.strip()

DF.apply(byeSpaces)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/830811132.py in <module>
#       1 byeSpaces= lambda column:column.str.strip()
#       2
# ----> 3 DF.apply(byeSpaces)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp/ipykernel_12024/830811132.py in <lambda>(column)
# ----> 1 byeSpaces= lambda column:column.str.strip()
#       2
#       3 DF.apply(byeSpaces)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
DF.dtypes
# Out:
# country         object
# totalgdp         int64
# agriculture%    object
# industry%       object
# service%        object
# agriculture$     int64
# industry$        int64
# service$         int64
# dtype: object

# %%
DF
# Out:
#             country   totalgdp agriculture% industry% service%  agriculture$  \
# 0             World  127800000         6.4%     30.0%    63.6%       8179200
# 1             China   23210000         7.9%     40.5%    51.6%       1833590
# 2    European Union   20850111         1.6%     25.1%    70.9%        333600
# 3     United States   19490000         0.9%     19.1%    80.0%        175410
# 4             India    9474000        15.4%     23.0%    61.5%       1458996
# ..              ...        ...          ...       ...      ...           ...
# 217        Anguilla        175         3.0%     10.5%    86.4%             5
# 218      Montserrat        167         1.9%      7.8%    90.3%             3
# 219           Nauru        160         6.1%     33.0%    60.8%            10
# 220          Tuvalu         42        24.5%      5.6%    70.0%            10
# 221            Niue         10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0     38340000  80514000
# 1      9400050  11976360
# 2      5233350  14782650
# 3      3722590  15592000
# 4      2179020   5826510
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [222 rows x 8 columns]

# %%
#I'll get rid of the first and the third (world and EU) rows.

# %%
whichToDrop=[0,2]

# %%
DF.drop(labels=DF.rows[whichToDrop],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/3834967315.py in <module>
# ----> 1 DF.drop(labels=DF.rows[whichToDrop],axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
DF.columns
# Out:
# Index(['country', 'totalgdp', 'agriculture%', 'industry%', 'service%',
#        'agriculture$', 'industry$', 'service$'],
#       dtype='object')

# %%
DF.drop(labels=DF.index[whichToDrop],axis=2,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/1765085326.py in <module>
# ----> 1 DF.drop(labels=DF.index[whichToDrop],axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: '[0 2] not found in axis'

# %%
DF.drop(labels=DF.index[whichToDrop],axis=2,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/722711016.py in <module>
# ----> 1 DF.drop(labels=DF.index[whichToDrop],axis=2,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4135             if index is not None or columns is not None:
#    4136                 raise ValueError("Cannot specify both 'labels' and 'index'/'columns'")
# -> 4137             axis_name = self._get_axis_name(axis)
#    4138             axes = {axis_name: labels}
#    4139         elif index is not None or columns is not None:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_name(cls, axis)
#     551     @classmethod
#     552     def _get_axis_name(cls, axis: Axis) -> str:
# --> 553         axis_number = cls._get_axis_number(axis)
#     554         return cls._AXIS_ORDERS[axis_number]
#     555
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
# --> 548             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     549
#     550     @final
#
# ValueError: No axis named 2 for object type DataFrame

# %%
DF.drop(labels=DF.index[whichToDrop],axis=0,inplace=True)

# %%
DF
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 1            China  23210000         7.9%     40.5%    51.6%       1833590
# 3    United States  19490000         0.9%     19.1%    80.0%        175410
# 4            India   9474000        15.4%     23.0%    61.5%       1458996
# 5            Japan   5443000         1.1%     30.1%    68.7%         59873
# 6          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 217       Anguilla       175         3.0%     10.5%    86.4%             5
# 218     Montserrat       167         1.9%      7.8%    90.3%             3
# 219          Nauru       160         6.1%     33.0%    60.8%            10
# 220         Tuvalu        42        24.5%      5.6%    70.0%            10
# 221           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 1      9400050  11976360
# 3      3722590  15592000
# 4      2179020   5826510
# 5      1638343   3739341
# 6      1289093   2880514
# ..         ...       ...
# 217         18       151
# 218         13       151
# 219         53        97
# 220          2        29
# 221          3         5
#
# [220 rows x 8 columns]

# %%
DF.reset_index(drop=True,inplace=True)

# %%
DF
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 215       Anguilla       175         3.0%     10.5%    86.4%             5
# 216     Montserrat       167         1.9%      7.8%    90.3%             3
# 217          Nauru       160         6.1%     33.0%    60.8%            10
# 218         Tuvalu        42        24.5%      5.6%    70.0%            10
# 219           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0      9400050  11976360
# 1      3722590  15592000
# 2      2179020   5826510
# 3      1638343   3739341
# 4      1289093   2880514
# ..         ...       ...
# 215         18       151
# 216         13       151
# 217         53        97
# 218          2        29
# 219          3         5
#
# [220 rows x 8 columns]

# %%
#Save it as CSV

# %%
#but first rename it:

# %%
DataGDP=DF.copy()

# %%
DataGDP
# Out:
#            country  totalgdp agriculture% industry% service%  agriculture$  \
# 0            China  23210000         7.9%     40.5%    51.6%       1833590
# 1    United States  19490000         0.9%     19.1%    80.0%        175410
# 2            India   9474000        15.4%     23.0%    61.5%       1458996
# 3            Japan   5443000         1.1%     30.1%    68.7%         59873
# 4          Germany   4199000         0.7%     30.7%    68.6%         29393
# ..             ...       ...          ...       ...      ...           ...
# 215       Anguilla       175         3.0%     10.5%    86.4%             5
# 216     Montserrat       167         1.9%      7.8%    90.3%             3
# 217          Nauru       160         6.1%     33.0%    60.8%            10
# 218         Tuvalu        42        24.5%      5.6%    70.0%            10
# 219           Niue        10        23.5%     26.9%    49.5%             2
#
#      industry$  service$
# 0      9400050  11976360
# 1      3722590  15592000
# 2      2179020   5826510
# 3      1638343   3739341
# 4      1289093   2880514
# ..         ...       ...
# 215         18       151
# 216         13       151
# 217         53        97
# 218          2        29
# 219          3         5
#
# [220 rows x 8 columns]

# %%
DataGDP.to_csv("DataGDP.csv",index=False)
