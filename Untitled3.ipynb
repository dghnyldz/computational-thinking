# %%
import pandas as pd

# %%
# link to the data in CSV format
linkFinalData='https://github.com/dghnyldz/computational-thinking/raw/main/FinalData.csv'

# using 'read_csv' with a link
FinalData=pd.read_csv(linkFinalData)

# %%
FinalData1=FinalData.copy()

# %%
WhenYouFind='\\%'
replaceWith=''

# %%
import re

# %%
FinalData1.columns.str.replace(WhenYouFind,replaceWith,regex=True).str()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/930306490.py in <module>
# ----> 1 FinalData1.columns.str.replace(WhenYouFind,replaceWith,regex=True).str()
#
# TypeError: 'StringMethods' object is not callable

# %%
FinalData
# Out:
#            Country  TotalGDPinMillions Agriculture% Industry% Service%  \
# 0            China            23210000         7.9%     40.5%    51.6%
# 1    United States            19490000         0.9%     19.1%    80.0%
# 2            India             9474000        15.4%     23.0%    61.5%
# 3            Japan             5443000         1.1%     30.1%    68.7%
# 4          Germany             4199000         0.7%     30.7%    68.6%
# ..             ...                 ...          ...       ...      ...
# 200       Anguilla                 175         3.0%     10.5%    86.4%
# 201     Montserrat                 167         1.9%      7.8%    90.3%
# 202          Nauru                 160         6.1%     33.0%    60.8%
# 203         Tuvalu                  42        24.5%      5.6%    70.0%
# 204           Niue                  10        23.5%     26.9%    49.5%
#
#      Agriculture$  Industry$  Service$ InternetccTLD ISO2 ISO3  CO2x1000  \
# ...

# %%
describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/2520863865.py in <module>
# ----> 1 describe
#
# NameError: name 'describe' is not defined

# %%
describe(FinalData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/2721815635.py in <module>
# ----> 1 describe(FinalData)
#
# NameError: name 'describe' is not defined

# %%
info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/4193362206.py in <module>
# ----> 1 info()
#
# NameError: name 'info' is not defined

# %%
FinalData.describe()
# Out:
#        TotalGDPinMillions  Agriculture$     Industry$      Service$  \
# count        2.050000e+02  2.050000e+02  2.050000e+02  2.050000e+02
# mean         6.104057e+05  3.787367e+04  1.816862e+05  3.901712e+05
# std          2.303504e+06  1.688836e+05  7.479346e+05  1.495049e+06
# min          1.000000e+01  0.000000e+00  0.000000e+00  5.000000e+00
# 25%          8.629000e+03  4.560000e+02  1.762000e+03  5.519000e+03
# 50%          6.197000e+04  5.170000e+03  1.465400e+04  3.085600e+04
# 75%          3.171000e+05  1.793500e+04  1.057060e+05  2.181520e+05
# max          2.321000e+07  1.833590e+06  9.400050e+06  1.559200e+07
#
#            CO2x1000    Population
# count  2.050000e+02  2.050000e+02
# mean   4.449892e+04  3.761999e+04
# std    2.271895e+05  1.451708e+05
# min    3.000000e+00  1.619000e+00
# 25%    3.280000e+02  8.884510e+02
# 50%    2.415000e+03  6.958532e+03
# 75%    1.632500e+04  2.578822e+04
# max    2.806634e+06  1.444216e+06

# %%
FinalData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             205 non-null    object
#  1   TotalGDPinMillions  205 non-null    int64
#  2   Agriculture%        205 non-null    object
#  3   Industry%           205 non-null    object
#  4   Service%            205 non-null    object
#  5   Agriculture$        205 non-null    int64
#  6   Industry$           205 non-null    int64
#  7   Service$            205 non-null    int64
#  8   InternetccTLD       205 non-null    object
#  9   ISO2                204 non-null    object
#  10  ISO3                205 non-null    object
#  11  CO2x1000            205 non-null    int64
#  12  Population          205 non-null    float64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 20.9+ KB

# %%
FinalData.value_counts()
# Out:
# Country        TotalGDPinMillions  Agriculture%  Industry%  Service%  Agriculture$  Industry$  Service$  InternetccTLD  ISO2  ISO3  CO2x1000  Population
# Afghanistan    69450               23.0%         21.1%      55.9%     15974         14654      38823     .af            AF    AFG   2675      39835.428     1
# Pakistan       1061000             24.4%         19.1%      56.5%     258884        202651     599465    .pk            PK    PAK   45350     225199.937    1
# Nepal          79190               27.0%         13.5%      59.5%     21381         10691      47118     .np            NP    NPL   2190      29674.920     1
# Netherlands    924400              1.6%          17.9%      70.2%     14790         165468     648929    .nl            NL    NLD   45624     17173.099     1
# New Caledonia  11110               1.4%          26.4%      72.1%     156           2933       8010      .nc            NC    NCL   1170      288.218       1
# ...

# %%
FinalData[Agriculture%].value_counts()
# Out:
#   File "C:\Users\dagha\AppData\Local\Temp/ipykernel_23352/1236007154.py", line 1
#     FinalData[Agriculture%].value_counts()
#                           ^
# SyntaxError: invalid syntax

# %%
FinalData[Agriculture].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/3965421323.py in <module>
# ----> 1 FinalData[Agriculture].value_counts()
#
# NameError: name 'Agriculture' is not defined

# %%
FinalData[2].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
FinalData.Agriculture%
# Out:
#   File "C:\Users\dagha\AppData\Local\Temp/ipykernel_23352/2279265529.py", line 1
#     FinalData.Agriculture%
#                           ^
# SyntaxError: invalid syntax

# %%
FinalData[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
FinalData.column[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/2036778420.py in <module>
# ----> 1 FinalData.column[2]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
FinalData1=FinalData.copy()

# %%
FinalData1
# Out:
#            Country  TotalGDPinMillions Agriculture% Industry% Service%  \
# 0            China            23210000         7.9%     40.5%    51.6%
# 1    United States            19490000         0.9%     19.1%    80.0%
# 2            India             9474000        15.4%     23.0%    61.5%
# 3            Japan             5443000         1.1%     30.1%    68.7%
# 4          Germany             4199000         0.7%     30.7%    68.6%
# ..             ...                 ...          ...       ...      ...
# 200       Anguilla                 175         3.0%     10.5%    86.4%
# 201     Montserrat                 167         1.9%      7.8%    90.3%
# 202          Nauru                 160         6.1%     33.0%    60.8%
# 203         Tuvalu                  42        24.5%      5.6%    70.0%
# 204           Niue                  10        23.5%     26.9%    49.5%
#
#      Agriculture$  Industry$  Service$ InternetccTLD ISO2 ISO3  CO2x1000  \
# ...

# %%
# all columns
FinalData.columns=['Country', 'TotalGDPinMillions', 'AgriPercent','InduPercent', 'ServPercent', 'AgriDollar', 'InduDollar', 'ServDollar', 'InternetccTLD', 'ISO2', 'ISO3', 'CO2x1000', 'Population']
#see changes:
FinalData.head()
# Out:
#          Country  TotalGDPinMillions AgriPercent InduPercent ServPercent  \
# 0          China            23210000        7.9%       40.5%       51.6%
# 1  United States            19490000        0.9%       19.1%       80.0%
# 2          India             9474000       15.4%       23.0%       61.5%
# 3          Japan             5443000        1.1%       30.1%       68.7%
# 4        Germany             4199000        0.7%       30.7%       68.6%
#
#    AgriDollar  InduDollar  ServDollar InternetccTLD ISO2 ISO3  CO2x1000  \
# 0     1833590     9400050    11976360           .cn   CN  CHN   2806634
# 1      175410     3722590    15592000           .us   US  USA   1432855
# 2     1458996     2179020     5826510           .in   IN  IND    610411
# 3       59873     1638343     3739341           .jp   JP  JPN    331074
# 4       29393     1289093     2880514           .de   DE  DEU    196314
#
#     Population
# 0  1444216.107
# 1   332915.073
# 2  1393409.038
# 3   126050.804
# ...

# %%
FinalData.AgriPercent
# Out:
# 0       7.9%
# 1       0.9%
# 2      15.4%
# 3       1.1%
# 4       0.7%
#        ...
# 200     3.0%
# 201     1.9%
# 202     6.1%
# 203    24.5%
# 204    23.5%
# Name: AgriPercent, Length: 205, dtype: object

# %%
FinalData.AgriPercent.value_counts()
# Out:
# 0.7%     5
# 1.8%     5
# 2.4%     4
# 0.0%     3
# 6.8%     3
#         ..
# 18.3%    1
# 10.1%    1
# 4.3%     1
# 23.4%    1
# 23.5%    1
# Name: AgriPercent, Length: 142, dtype: int64

# %%
FinalData[['AgriPercent']] = FinalData[['AgriPercent']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "7.9%"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/3199073060.py in <module>
# ----> 1 FinalData[['AgriPercent']] = FinalData[['AgriPercent']].apply(pd.to_numeric)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# ...

# %%
FinalData
# Out:
#            Country  TotalGDPinMillions AgriPercent InduPercent ServPercent  \
# 0            China            23210000        7.9%       40.5%       51.6%
# 1    United States            19490000        0.9%       19.1%       80.0%
# 2            India             9474000       15.4%       23.0%       61.5%
# 3            Japan             5443000        1.1%       30.1%       68.7%
# 4          Germany             4199000        0.7%       30.7%       68.6%
# ..             ...                 ...         ...         ...         ...
# 200       Anguilla                 175        3.0%       10.5%       86.4%
# 201     Montserrat                 167        1.9%        7.8%       90.3%
# 202          Nauru                 160        6.1%       33.0%       60.8%
# 203         Tuvalu                  42       24.5%        5.6%       70.0%
# 204           Niue                  10       23.5%       26.9%       49.5%
#
# ...

# %%
import re

# %%
FinalData.series=FinalData.series.str.replace("\\%","",regex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/3618154976.py in <module>
# ----> 1 FinalData.series=FinalData.series.str.replace("\\%","",regex=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'series'

# %%
FinalData.Series=FinalData.Series.str.replace("\\%","",regex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/2734285718.py in <module>
# ----> 1 FinalData.Series=FinalData.Series.str.replace("\\%","",regex=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
FinalData["AgriPercent"]= FinalData["AgriPercent"].replace("%", "")

# %%
FinalData
# Out:
#            Country  TotalGDPinMillions AgriPercent InduPercent ServPercent  \
# 0            China            23210000        7.9%       40.5%       51.6%
# 1    United States            19490000        0.9%       19.1%       80.0%
# 2            India             9474000       15.4%       23.0%       61.5%
# 3            Japan             5443000        1.1%       30.1%       68.7%
# 4          Germany             4199000        0.7%       30.7%       68.6%
# ..             ...                 ...         ...         ...         ...
# 200       Anguilla                 175        3.0%       10.5%       86.4%
# 201     Montserrat                 167        1.9%        7.8%       90.3%
# 202          Nauru                 160        6.1%       33.0%       60.8%
# 203         Tuvalu                  42       24.5%        5.6%       70.0%
# 204           Niue                  10       23.5%       26.9%       49.5%
#
# ...

# %%
FinalData.dtypes
# Out:
# Country                object
# TotalGDPinMillions      int64
# AgriPercent            object
# InduPercent            object
# ServPercent            object
# AgriDollar              int64
# InduDollar              int64
# ServDollar              int64
# InternetccTLD          object
# ISO2                   object
# ISO3                   object
# CO2x1000                int64
# Population            float64
# dtype: object

# %%
FinalData[['AgriPercent']] = FinalData[['AgriPercent']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "7.9%"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23352/3199073060.py in <module>
# ----> 1 FinalData[['AgriPercent']] = FinalData[['AgriPercent']].apply(pd.to_numeric)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# ...

# %%
FinalData.AgriPercent=FinalData.AgriPercent.str.replace("%","",regex=True)

# %%
FinalData
# Out:
#            Country  TotalGDPinMillions AgriPercent InduPercent ServPercent  \
# 0            China            23210000         7.9       40.5%       51.6%
# 1    United States            19490000         0.9       19.1%       80.0%
# 2            India             9474000        15.4       23.0%       61.5%
# 3            Japan             5443000         1.1       30.1%       68.7%
# 4          Germany             4199000         0.7       30.7%       68.6%
# ..             ...                 ...         ...         ...         ...
# 200       Anguilla                 175         3.0       10.5%       86.4%
# 201     Montserrat                 167         1.9        7.8%       90.3%
# 202          Nauru                 160         6.1       33.0%       60.8%
# 203         Tuvalu                  42        24.5        5.6%       70.0%
# 204           Niue                  10        23.5       26.9%       49.5%
#
# ...

# %%
FinalData.InduPercent=FinalData.InduPercent.str.replace("%","",regex=True)

# %%
FinalData.ServPercent=FinalData.ServPercent.str.replace("%","",regex=True)

# %%
FinalData
# Out:
#            Country  TotalGDPinMillions AgriPercent InduPercent ServPercent  \
# 0            China            23210000         7.9        40.5        51.6
# 1    United States            19490000         0.9        19.1        80.0
# 2            India             9474000        15.4        23.0        61.5
# 3            Japan             5443000         1.1        30.1        68.7
# 4          Germany             4199000         0.7        30.7        68.6
# ..             ...                 ...         ...         ...         ...
# 200       Anguilla                 175         3.0        10.5        86.4
# 201     Montserrat                 167         1.9         7.8        90.3
# 202          Nauru                 160         6.1        33.0        60.8
# 203         Tuvalu                  42        24.5         5.6        70.0
# 204           Niue                  10        23.5        26.9        49.5
#
# ...

# %%
FinalData.dtypes
# Out:
# Country                object
# TotalGDPinMillions      int64
# AgriPercent            object
# InduPercent            object
# ServPercent            object
# AgriDollar              int64
# InduDollar              int64
# ServDollar              int64
# InternetccTLD          object
# ISO2                   object
# ISO3                   object
# CO2x1000                int64
# Population            float64
# dtype: object

# %%
FinalData[['AgriPercent']] = FinalData[['AgriPercent']].apply(pd.to_numeric)

# %%
FinalData.dtypes
# Out:
# Country                object
# TotalGDPinMillions      int64
# AgriPercent           float64
# InduPercent            object
# ServPercent            object
# AgriDollar              int64
# InduDollar              int64
# ServDollar              int64
# InternetccTLD          object
# ISO2                   object
# ISO3                   object
# CO2x1000                int64
# Population            float64
# dtype: object

# %%
FinalData[['InduPercent']] = FinalData[['InduPercent']].apply(pd.to_numeric)

# %%
FinalData[['ServPercent']] = FinalData[['ServPercent']].apply(pd.to_numeric)

# %%
FinalData.dtypes
# Out:
# Country                object
# TotalGDPinMillions      int64
# AgriPercent           float64
# InduPercent           float64
# ServPercent           float64
# AgriDollar              int64
# InduDollar              int64
# ServDollar              int64
# InternetccTLD          object
# ISO2                   object
# ISO3                   object
# CO2x1000                int64
# Population            float64
# dtype: object

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(FinalData,file="FinalData.RDS")
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x000002CA76A2B800> [RTYPES.NILSXP]
